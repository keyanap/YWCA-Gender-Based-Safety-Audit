# %% [markdown]
# # Hate Crimes as Reported by Hamilton Police Services 2019-2023

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import date
from pathlib import Path
today = date.today()

# %%
# Load file
data_path = Path("Resources/Hate Crimes - HPS - 2019-2023.xlsx")

# Read in the data
hate_crimes = pd.read_excel(data_path)

# Display the data
hate_crimes.head()
# Out:
#         Date  Age - Bias  Disability - Bias  Language - Bias  \
# 0 2019-12-31           0                  0                0
# 1 2020-12-31           0                  0                0
# 2 2021-12-31           0                  0                0
# 3 2022-12-31           0                  0                0
# 4 2023-12-31           0                  0                1
#
#    Gender Identity - Bias  Sex - Bias  Sexual Orientation - Bias   \
# 0                       4           0                           8
# 1                       3           0                           1
# 2                       1           0                          14
# 3                       9           0                          19
# 4                       5           0                          18
#
#    Similar Factor - Bias  Racial - Bias  Religion - Bias  ...  \
# 0                      0             34               38  ...
# 1                      0             38               30  ...
# ...

# %%
# Create DataFrame
hate_crimes_df = pd.DataFrame(hate_crimes)

# Display the data
hate_crimes_df.head()
# Out:
#         Date  Age - Bias  Disability - Bias  Language - Bias  \
# 0 2019-12-31           0                  0                0
# 1 2020-12-31           0                  0                0
# 2 2021-12-31           0                  0                0
# 3 2022-12-31           0                  0                0
# 4 2023-12-31           0                  0                1
#
#    Gender Identity - Bias  Sex - Bias  Sexual Orientation - Bias   \
# 0                       4           0                           8
# 1                       3           0                           1
# 2                       1           0                          14
# 3                       9           0                          19
# 4                       5           0                          18
#
#    Similar Factor - Bias  Racial - Bias  Religion - Bias  ...  \
# 0                      0             34               38  ...
# 1                      0             38               30  ...
# ...

# %%
# Check data types
hate_crimes_df.dtypes
# Out:
# Date                              datetime64[ns]
# Age - Bias                                 int64
# Disability - Bias                          int64
# Language - Bias                            int64
# Gender Identity - Bias                     int64
# Sex - Bias                                 int64
# Sexual Orientation - Bias                  int64
# Similar Factor - Bias                      int64
# Racial - Bias                              int64
# Religion - Bias                            int64
# Age - Motivated                            int64
# Disability - Motivated                     int64
# Language -Motivated                        int64
# Gender Identity - Motivated                int64
# Sex - Motivated                            int64
# Sexual Orientation - Motivated             int64
# Similar Factor - Motivated                 int64
# Racial - Motivated                         int64
# Religion - Motivated                       int64
# ...

# %%
# Set index to 'Date' column
hate_crimes_df = hate_crimes_df.set_index('Date')

# Display the data
hate_crimes_df.head()
# Out:
#             Age - Bias  Disability - Bias  Language - Bias  \
# Date
# 2019-12-31           0                  0                0
# 2020-12-31           0                  0                0
# 2021-12-31           0                  0                0
# 2022-12-31           0                  0                0
# 2023-12-31           0                  0                1
#
#             Gender Identity - Bias  Sex - Bias  Sexual Orientation - Bias   \
# Date
# 2019-12-31                       4           0                           8
# 2020-12-31                       3           0                           1
# 2021-12-31                       1           0                          14
# 2022-12-31                       9           0                          19
# 2023-12-31                       5           0                          18
#
#             Similar Factor - Bias  Racial - Bias  Religion - Bias  \
# Date
# 2019-12-31                      0             34               38
# ...

# %%
# Lines for the plot
plt.plot(hate_crimes_df.index, hate_crimes_df['Total - Bias'])
plt.plot(hate_crimes_df.index, hate_crimes_df['Total - Motivated '])
plt.plot(hate_crimes_df.index, hate_crimes_df['Overall Total'])

# Title of the plot
plt.title('Total Hate Crimes in Hamilton (2019-2023)')
# Bold title
plt.title('Total Hate Crimes in Hamilton (2019-2023)', fontweight='bold')

# Labels for the x and y axis
plt.xlabel('Date')
plt.ylabel('Number of Crimes')

# Place x ticks
plt.xticks(rotation=30, fontsize=10)

# Legend
plt.legend(['Total - Bias', 'Total - Motivated ', 'Overall Total'])

# Plot the data
plt.show()

# Save the plot
#plt.savefig(f"Images/Hate_Crimes_Hamilton_2019-2023.png")

# %%
# Lines for the plot
plt.plot(hate_crimes_df.index, hate_crimes_df['Gender Identity - Bias'], linestyle='dashed', color='blue')
plt.plot(hate_crimes_df.index, hate_crimes_df['Gender Identity - Motivated '], color='blue')
plt.plot(hate_crimes_df.index, hate_crimes_df['Sex - Bias'], linestyle='dashed', color='green')
plt.plot(hate_crimes_df.index, hate_crimes_df['Sex - Motivated'], color='green')
plt.plot(hate_crimes_df.index, hate_crimes_df['Sexual Orientation - Bias '], linestyle='dashed', color='orange')
plt.plot(hate_crimes_df.index, hate_crimes_df['Sexual Orientation - Motivated'], color='orange')

# Title of the plot
plt.title('Hate Crimes in Hamilton (2019-2023)')
# Bold title
plt.title('Hate Crimes in Hamilton (2019-2023)', fontweight='bold')

# Labels for the x and y axis
plt.xlabel('Date')
plt.ylabel('Number of Crimes')

# Place x ticks
plt.xticks(rotation=30, fontsize=10)

# Legend
plt.legend(['Gender Identity - Bias', 'Gender Identity - Motivated ', 'Sex - Bias', 'Sex - Motivated', 
            'Sexual Orientation - Bias ', 'Sexual Orientation - Motivated'])

# Plot the data
plt.show()

# Save the plot
#plt.savefig(f"Images/Hate_Crimes_Hamilton_2019-2023.png")

# %%
plt.plot(hate_crimes_df.index, hate_crimes_df['Racial - Bias'], linestyle='dashed', color='blue')
plt.plot(hate_crimes_df.index, hate_crimes_df['Racial - Motivated'], color='blue')
plt.plot(hate_crimes_df.index, hate_crimes_df['Religion - Bias'], linestyle='dashed', color='green')
plt.plot(hate_crimes_df.index, hate_crimes_df['Religion - Motivated'], color='green')
plt.plot(hate_crimes_df.index, hate_crimes_df['Language - Bias'], linestyle='dashed', color='orange')
plt.plot(hate_crimes_df.index, hate_crimes_df['Language -Motivated'], color='orange')

# Title of the plot
plt.title('Hate Crimes in Hamilton (2019-2023)')
# Bold title
plt.title('Hate Crimes in Hamilton (2019-2023)', fontweight='bold')

# Labels for the x and y axis
plt.xlabel('Date')
plt.ylabel('Number of Crimes')

# Place x ticks
plt.xticks(rotation=30, fontsize=10)

# Legend
plt.legend(['Racial - Bias','Racial - Motivated','Religion - Bias',
           'Religion - Motivated', 'Language - Bias',
            'Language -Motivated'])

# Plot the data
plt.show()

# Save the plot
#plt.savefig(f"Images/Hate_Crimes_Hamilton_2019-2023.png")
